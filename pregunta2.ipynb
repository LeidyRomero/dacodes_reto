# %% [markdown]
# # 1. Enunciado
# Los archivos places_details.csv y places_reviews.csv contienen información sobre reseñas que
# han dejado diversos usuarios a múltiples restaurantes. Para este ejercicio, solicitamos que
# resumas los principales temas que mencionan los comensales al momento de dejar una reseña
# (Hint: Sabor, variedad, servicio, etc).

# %% [markdown]
# # 2. Solución

# %% [markdown]
# ## 2.1. Configuración e importe de paquetes

# %%
# !pip install gensim nltk
# !pip install googletrans==4.0.0-rc1
# !pip install --upgrade nbformat
# !pip install bertopic
# Out:
# Requirement already satisfied: gensim in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (4.3.2)
# Requirement already satisfied: nltk in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from gensim) (1.11.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: click in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.7.22)
# Requirement already satisfied: hstspreload in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.1.1)
# Requirement already satisfied: sniffio in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: bertopic in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (1.24.3)
# Requirement already satisfied: hdbscan>=0.8.29 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (2.0.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (1.3.0)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from bertopic) (5.16.1)
# Requirement already satisfied: cython<3,>=0.27 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.11.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from plotly>=4.7.0->bertopic) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.32.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: nltk in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.4)
# Requirement already satisfied: colorama in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.49 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.57.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.5.10)
# Requirement already satisfied: filelock in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.3)
# Requirement already satisfied: fsspec in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.40.1)
# Requirement already satisfied: six>=1.5 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.8.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.3.3)
# Requirement already satisfied: click in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\leidy\miniconda3\envs\asistencia\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from gensim import models, corpora
nltk.download('stopwords')
import os
import pandas as pd
import unicodedata
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\leidy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# A continuación se definen las constantes del código, en este caso la ubicación de los datos

# %%
DATA_PATH = os.path.join('data')

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Tokenize
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('spanish'))
    tokens = [token for token in tokens if token not in stop_words]
    
    return tokens

from googletrans import Translator, LANGUAGES

def translate_to_spanish(text, source_language='en'):
    try:
        translator = Translator()
        translated = translator.translate(text, src=source_language, dest='es')
        return translated.text
    except:
        return ''

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

# %% [markdown]
# ## 2.2. Carga de datos
# Se cuenta con 9183 registros, de los cuales 317 son duplicados y se eliminan quedando con 8866 registros, descritos con 33 variables. Se observa una muestra de 5 registros

# %%
detalles = pd.read_csv(os.path.join(DATA_PATH, 'places_details (3) (1).csv'))
reviews = pd.read_csv(os.path.join(DATA_PATH, 'places_reviews (3) (1) (2).csv'))
datos = pd.merge(detalles, reviews, on=['place_id'], how='inner')
print('Número de registros duplicados: ', datos.duplicated().sum())
datos.drop_duplicates(inplace=True)
print('Número de filas y columnas:', datos.shape)
display(datos.language.value_counts())
# Aplicar la función a la columna 'Texto'
datos['text'] = datos['text'].apply(remove_accents)

datos_es = datos[datos['language'].isin(['es'])]
datos_en = datos[datos['language']=='en']

datos_en['text'] = datos_en['text'].apply(translate_to_spanish)
datos_en = datos_en[datos_en['text']!='']
datos_new = pd.concat([datos_en, datos_es])

textos = datos_new['text'].apply(preprocess_text)

textos
# Out:
# Número de registros duplicados:  317
# Número de filas y columnas: (8866, 33)
# language
# es         8371
# en          424
# pt           23
# sl           11
# fr            6
# id            2
# sv            2
# ko            2
# ar            2
# gl            2
# ja            2
# de            2
# zh            2
# pl            2
# hi            2
# zh-Hant       2
# it            2
# fi            1
# tr            1
# ro            1
# ca            1
# ru            1
# ku            1
# cs            1
# Name: count, dtype: int64
# C:\Users\leidy\AppData\Local\Temp\ipykernel_8568\4072016196.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_en['text'] = datos_en['text'].apply(translate_to_spanish)
# 33      [bonito, restaurante, buena, comida, instalaci...
# 81                                                     []
# 156                                              [fresco]
# 217     [comida, realmente, sabrosa, restaurante, vist...
# 230      [gran, servicio, celebramos, cumpleanos, genial]
#                               ...
# 9178    [good, place, to, eat, traditional, food, from...
# 9179    [meseros, siempre, mala, cara, tortas, ahogada...
# 9180                            [ricas, tortas, ahogadas]
# 9181    [riquisimo, tortas, ahogadas, tacos, dorados, ...
# 9182    [perfeccion, existe, doy, 4, estrellas, delici...
# Name: text, Length: 8790, dtype: object

# %%
preprocessed_reviews = textos.tolist() # Your list of reviews

# %%
# Create a dictionary
dictionary = corpora.Dictionary(preprocessed_reviews)

# Create a corpus
corpus = [dictionary.doc2bow(review) for review in preprocessed_reviews]

# %%
# Train the LDA model
lda_model = models.LdaModel(corpus, id2word=dictionary, num_topics=5, passes=15)

# Print the topics
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.065*"rico" + 0.028*"super" + 0.026*"tacos" + 0.025*"buenos" + 0.019*"ricos" + 0.015*"delicioso" + 0.013*"bien" + 0.013*"servicio" + 0.011*"siempre" + 0.011*"exelente"
# Topic 1: 0.023*"bien" + 0.015*"si" + 0.015*"mas" + 0.012*"buenas" + 0.012*"bueno" + 0.012*"solo" + 0.010*"tortas" + 0.009*"tacos" + 0.008*"sabor" + 0.008*"estan"
# Topic 2: 0.088*"lugar" + 0.049*"buen" + 0.034*"excelente" + 0.028*"buena" + 0.028*"atencion" + 0.025*"comida" + 0.019*"comer" + 0.019*"sabor" + 0.016*"servicio" + 0.015*"agradable"
# Topic 3: 0.073*"comida" + 0.060*"excelente" + 0.046*"servicio" + 0.019*"buena" + 0.017*"rica" + 0.017*"atencion" + 0.016*"deliciosa" + 0.016*"mejor" + 0.014*"precio" + 0.011*"buen"
# Topic 4: 0.028*"delicioso" + 0.025*"mas" + 0.010*"experiencia" + 0.010*"menu" + 0.009*"si" + 0.008*"gusto" + 0.006*"restaurante" + 0.005*"cada" + 0.005*"mejor" + 0.004*"tiempo"

# %% [markdown]
# ## 2.3. Embbedings

# %%
from bertopic import BERTopic

# %%
textos = datos['text'].apply(preprocess_text)
textos = [' '.join(texto) for texto in textos if len(texto)>0]
textos
# Out:
# ['bonito restaurante buena comida instalaciones limpias personal amable acuerdo comida lleva mas tiempo terrible',
#  'fresco',
#  'comida realmente sabrosa restaurante vista increible recomiendo sentarme afuera',
#  'gran servicio celebramos cumpleanos genial',
#  'deliciosa comida buen servicio limpio pacifico lugar necesita mantenimiento',
#  'buen restaurante ciudad mexico restaurante elegante vecindario seguro costoso',
#  'mejores lugares comer mexico temporada lluvias puedes perderte escamoles',
#  'acuerdo',
#  'conoci amigos hos hos b aqui aprendi mexicano cerni esada genial 10 10',
#  'siempre excelente servicio comida',
#  'extraordinario',
#  'acuerdo',
#  'lugar excelente comer hamburgoues hijo deliciosas definitiva reina hamburguesas',
#  'encanta',
#  'mmm delicioso',
#  'super',
#  'finalmente buen restaurante tambien muchas opciones excelentes menu vino casa roja bueno shiraz servicio perfecto canasta pan excelente restaurante ligeramente formal limpio servicio atento profesional definitivamente volveria probar menu cena',
#  'comida absolutamente increible gran sumiller personal ubicacion perfecta ver distrito historico ciudad mexico',
#  'gran servicio lindo',
#  'comida sabrosa',
#  'bien',
#  'super rico',
#  'excelente servicio ambiente toda gente funciona bien',
#  'super',
#  'super calificacion porciones pequenas caras obtienes recomiendo lugar absoluto',
#  'deliciosos mejores tacos pescado excelente seleccion salsa tambien',
#  'encanto comida bistec delicioso igual fideo menu general comida variado menus bebidas vino tambien geniales servicio excepcional rapido amigable eficiente terraza aire libre acogedora agradable restaurantes guadiana definitivamente mejores comer excelente comida mexicana ciudad mexico',
#  'comida realmente buena aunque si desea tener problemas obtener factura lugar pase 15 minutos tratando recibir factura correo electronico',
#  'buena comida servicio perfecto descubrir rica cocina mexicana ambiente exclusivo',
#  'bonito restaurante exclusivo cadena hotelera favorita mexico acebra vivo restaurante sirve comida mexicana estilo baja parece mas obtenemos california equivoque cocina buena coleccion tequila demasiado probar noche realmente recuerdo platos noche excepto taco camarones estilo baja plato carne par recuerdo nombres bien volvere decoracion moderna acogedora grupos fumaban ruidosos pedimos sentaran area diferente bien',
#  'excelente comida servicio decoracion mexicanos mejores restaurantes ciudad mexico',
#  'fiambres',
#  'delicio comida servicio excelentes',
#  'buena comida servicio demasiado ruidoso',
#  'experiencia alimentaria increible lugar sorprendente imprescindible',
#  'mejor vista',
#  'amo lugar',
#  'definitivamente vale pena ir',
#  'caro',
#  'gran lugar vista amor caro',
#  'excelente servicio coctel mezcalita increible',
#  'costoso hermosa vista bebidas excelente sabor si alguna vez ciudad nuevamente volvere visitar lugar',
#  'lugar increible posiblemente comida favorita viaje bebidas excelentes fotogenicas alimento habiamos pedido bistec ravioles confitados pato ambos cocinados sazonados perfectamente postre teniamos menu degustacion 5 postres cada unico sabroso primero incluso consiguio experiencia interactiva especial ir cocina personal amable profesional servicial vistas restaurante increibles definitivamente regresaremos proxima vez',
#  'realmente bonito lugar disfrutar vista centro ciudad mexico disfrute brunch precio buena calidad continue manera',
#  'cuidado turistas lugar intentara estafarte comenzamos agradablemente disfrutamos comida medicore buen vino solo ser frustrados intento estafa final comida camarera trajo proyecto ley habia atendido dio pestana escrita mano luego inmediatamente dijo lector tarjetas trabajando tendriamos pagar efectivo miramos factura vimos habian cobrado mas cada articulo figuraba botellas agua menu enumeraron 25 pesos 3 escribieron 150 mx pizzas cosian 110 menu habian enumerado 120 vino cobraron pesos 210 pudimos disputar desafortunadamente enumeraban vino menu cobraron 4 lugar 3 dijimos solo teniamos tarjeta dijeron si estabanpodria hacer cargo tarjeta parcial cargo efectivo parcial todavia momento estabamos tan frustrados solo queriamos irnos hicimos aceptaran precios menu publicados camarero afirmo recargo propina bueno consejo lastima lugar podria ser genial incluso comida basura',
#  'ver comida servicio excelentes embargo dejes vendedores calle lleven restaurante diferente verdadero restaurante traves lobby hotel joyeria',
#  'buena comida increible vista encantador equipo servicio encantador tenia menu degustacion podria haberlo disfrutado mas',
#  'reserve anticipacion obtenga mesa lado balcon vista increible noche comida wow mejor comida mexico recomiendo encarecidamente',
#  'increible explosion sabor boca imprescindible si visitando cdmx beginnkng camareros servidores ambiente hace comida agradable',
#  'descargo responsabilidad plebeyo gustos reflejan restaurante paladares discriminantes pequenas barrigas grandes billeteras servicio 10 5 vistas 10 5 ambiente 10 5 comida buena describe gustos cocina local acuerdo cantidad pequena familia ninos economico comparacion favorito ahora cardinal pesar todavia recomiendo lugar parejas jovenes personas buscan salir fecha etc sabes ambiente serenata',
#  'mejor birria ciudad',
#  'birria plato tradicional jalisco receta preparacion lugar realmente honra tradicion original tortillas hechas mano sabrosa salsa picante olvide pedir jericalla postre',
#  'gran decoracion servicio suficientemente bueno enchiladas increibles',
#  'excelente lugar buena comida mexicana peruana',
#  'espanol ingles hablan recomiende sopa maiz lomo salado enchiladas camarones cangrejo puede ser fuerte interesante decoracion gran servicio',
#  'comida consistentemente buena seleccion vinos decente',
#  'comida servicio decoracion bueno',
#  'buena comida',
#  'buen restaurante santa fe opciones carne pescado',
#  'fiambres',
#  'gran opcion preuviano cusine ceviches frescos deliciosos tostones aperitivos increibles tambien pollo cuzco cocinado perfeccion tambien pedimos sorbetes frescos conclusion perfecta comida gran ambiente personal amable bien capacitado recomiendo almuerzo especial cena romantica',
#  'camarones madera excelentes gastado comida servicio excelentes',
#  'super',
#  'super',
#  'realmente gusto espagueti arroz crema frios empanadas dulces jamon adentro pibil cochinita salado tambien lunar dulce supuestamente dulce probe comida horrible',
#  'fantastico hallazgo linea locales buena senal decepciono',
#  'bonito lugar sabrosa comida mexicana',
#  'maravilloso restaurante experiencia verdaderamente agradable declaracion mision recrear comidas entretenimiento mas tradicionales cocteles estan hechos mano alta calidad incluida deliciosa comida desiertos ultimo servicio excelente miembros personal restaurante visita obligada obtener comida alta calidad inspiracion tradicional',
#  'excelente lugar cenar excelente ambiente excelente comida bistec guarniciones postre tenia sabores realmente agradables',
#  'lugar increible personal bar camarero anfitriona agradables presentacion alimentos bebidas mas alla expectativas',
#  'buena comida ambiente realmente divertido seguro volvere proxima vez ciudad',
#  'buena comida dirigido verdadero chef buen ambiente estudiantil',
#  'agradable venir espacio pasar buen dia tarde buena comida personal realmente agradable menu buenas opciones sabrosas',
#  'recomendado chef nico despues gira comida caminar debe comer lugar si visita cdmx',
#  'nuevo restaurante mexicano favorito ciudad comida deliciosa inspirada servicio competente amigable dueno sentado mesa junto presento encanta lugar recomiendo',
#  'entro grandes esperanzas decepcionadas comida equilibrada si cangrejo azul acido panceta cerdo demasiado grasosa cocinaba suficiente carne humeda oportunidad mejorar volveremos visitar futuro',
#  'ingredientes alta calidad ejecutados bien mayor parte pulpo demasiado cocido servicio pobre consideraria visitar nuevamente buen valor precio',
#  'experiencia tan deliciosa delicioso',
#  'caro originalmente ibamos restaurante vecino aqui cierran extranamente temprano cena asi decidimos probarlo comida creativa diria ensalada nopal demasiado salada',
#  'bastante decepcionante comida sola nota suficientemente sazonada suficiente cancelar resto pedido salir temprano bar vinos menu vinos ligero raramente dejo malas criticas senti obligado aqui',
#  'novio obtuvimos 5 tostadas diferentes todas super frescas deliciosas incluso vegetariana dejo boquiabiertos menu dia incluye ensalada sopa agua fresca tostada eleccion postre precio razonable recomendable',
#  'restaurante pequeno alrededor 8 mesas 4 personal super agradable servicial servicio rapido bueno comida absolutamente deliciosa pequena sopa tostadas tuna fresco sabroso sabores pagarias mas regreso casa solo opcion segura sino emocionante almuerzo cena',
#  'mejor restaurante vecindario desayuno almuerzo cena super servicio excelente conversacion compania mas rico',
#  'increible restaurante caro embargo verdadera experiencia culinaria gran ambiente',
#  'acepte perros chihuahua incluso mochila',
#  'hermoso ambiente deliciosa comida servicio encantador atento anfitriona acogedor parecia infeliz aparte definitivamente recomiendo lugar pollo tacos pescado pastor fabulosos reservas hicieron mesa abierta disfrutar',
#  'buena comida lugar increible',
#  'ambiente increible comida mediocre',
#  'fantastico servicio comida deliciosa',
#  'sabado noche comida bastante buena bien presentada embargo servicio horrible sentado rapidamente reserva dio menus 15 minutos momento amigo mexicano pedirlos luego pedir nuevamente lista vinos luego marcar camarero tomar pedido servicio coincidio precios cobra lugar',
#  'gran experiencia deliciosa comida buen servicio ambiente',
#  'vino agradable',
#  'buen ambiente agradable charla intima amigo cita tome copa bar probe comida diseno arquitectura espacio impresionantes decoracion varia original creativa ocupada pegajosa gran servicio general gran espacio intimo',
#  'comida realmente deliciosa servicio increible justifica precio malinterpreten delicioso realmente caro excelente experiencia gastronomica si buscando mas elegante exclusivo lugar ir',
#  'grande espanol significa grande jugo naranja fresco',
#  'bien',
#  'delicioso excelente servicio excelente ubicacion ceno septiembre 2020',
#  'ja ja bien bien amigos mejor alemania',
#  'buen ambiente excelente servicio platos tambien buenos puedes pasar hermosa manana desayunando incluso mas aqui',
#  'servicio bueno',
#  'buen posole sensacion hogarena dos damas ejecutan agradables solo pequeno agujero pared favorito',
#  'super guay',
#  'bonitos tacos demasiada grasa servicio tambien excelente',
#  'buscas deliciosa comida mexicana autentica area busques mas mejores platos tipicos puede obtener area establecimiento humilde hace proporcionar servicio comida eficiente rapida local the chickly pedimos segundos',
#  'super',
#  'mejor experiencia gastronomica guacamole salmon pulpo incluso postre deliciosos bebidas dios mio tambien bueno margaritas perfectas servicio atencion detalle ambiente hicieron noche memorable recomendaria cualquiera experimente lugar arrepentiras',
#  'gran ambiente increible cocina mexicana lugares favoritos condeza',
#  'realmente disfrute enchiladas pense hermosos deliciosos amigo consiguio salmon aunque tambien sabroso simple podria usar animarlo cocteles encantadores bruxo mezcal favorito',
#  'guau increible recomendable',
#  'grandes margaritas tortas',
#  'grandes bebidas comida celebro cumpleanos personal agradable ocupado lleno onna miercoles 815 pm estilo sudamericano menu comida mexicana',
#  'buen sabor buen ambiente',
#  'lugar agradable puede ser ruidoso comida buena favorita pulpo asado chevice camaronones bebidas pedimos coctel mezcal oaxaca 86 acuoso sabor',
#  'delicioso ceviche langostinos mango lima bastante inolvidable servicio excepcional preguntar varias veces vaso agua embargo medio ambiente genial cocina abierta vale pena visitar',
#  'comida maravillosa',
#  'buenos hombres',
#  'sabroso aunque caro obtienes',
#  'servicio educado bastante bien informado recomendaciones bebidas podrian ser refinadas bebida combino bien comida tambien bastante lleno platos destinados vegetarianos omnivoros lunar maiz absolutamente maravillosos embargo ofrendas vegetarianas parecian tan pensadas complejas oferta omnivora encantaron unicas luces foco plato hacia sentir comiendo obra arte texturas sabores mayoria platos equilibrados deliciosos traeria amigos ciudad experiencia espero trabajen mas ofertas vegetarianas desearia parecieran tan atractivos placas verduras ojala haber experimentado lugaresz',
#  'lugar comida servicio valen cada centavo',
# ...
#  'delicioso',
#  'buen servicio barra excelente',
#  'robano sal bastente regular quizas suerte',
#  'excelente comida eapacio atencion precio',
#  'excelente precio elevado',
#  'excelente servicio',
#  'mejores restaurantes ciudad mexico excelente servicio menu nacional',
#  'excelente comida deliciosa ambiente familiar lugar agradable ir familia pareja simplemente amig s',
#  'lugar super hogareno bonito bien cuidado comida yucateca 100 deliciosa panuchos pasando cochinita marquesitas nutela queso bola decir atencion atencion super esmerada muchachos mejor sonrisa chica atendio mesa si tenia cubreboca ojos decian ingrid hizo sentir mejor casa spa consentido primer lugar tratan chela reina',
#  'rica comida excelente servicio',
#  'mejor lugar comida yucateca 100 recomendado',
#  'riquisimo excelentes normas higiene',
#  'buen servicio magnificas instalaciones excelente comida',
#  'excelente servicio comida deliciosa mejor probado merida',
#  'deliciosa comida cumpliendo todas reglas sanitizacion mas',
#  'sopa lima buena platos compartir deliciosos',
#  'excelente lindo lugar',
#  'reencuentro lugares comida tipica tradicional diferente regiones pais lugar parece excelente sopa lima pollito pibil riquisimos recomendable atencion personalizada agradable gracias hanal ku pronto regresaremos',
#  'variedad precios adecuados',
#  'fin yucateco buscado hace anos lugar pueda probar verdadera sazon tierra lugares inst nacional chocinita habanerito polas cochinita contry peor humbertos sabe bien comida yucateca precios estan bien sazon increible cerveza patito champolas salbutes debe ser',
#  'super recomendable',
#  'riquisimos',
#  'excelente lugar comer comida yucateca buen servicio precios accesibles',
#  'recomendable bonito lugar',
#  'sopas excelentes',
#  'lugar agradable buen sazon platillos precios accesibles regresado varias ocasiones',
#  'esperaba mit rico mas menos',
#  'calido buen servicio exelente comida buen ambiente recomendado',
#  'buen pan atencion',
#  'buena comida yucateca buen servicio',
#  'excelente lugar comida yucateca',
#  'atencion buena pedi vaporcitos tamales yucatecos faltaba mas suavidad despues pedi queso relleno gusto mas tortillas hechas mabo pequenas bien tome cafe irlandes bueno preparan mesa asi plus precios estan mal lugar uba casa buenas condiciones si ser domingo habia pianista tocando musica boleros trova',
#  'buena comida buen servicio carta variada',
#  'bueno creo paso sal',
#  'delicioso gran variedad alimentos yucatecos champolas queso relleno preferidos',
#  'confirmado buena opcion degustar comida yucateca tipica combinado buen servicio precios razonables',
#  'deficiente servicio',
#  'parece cambio administracion servicio bueno comida bajo calidad dulcesitos daban salir sustituyeron cambio bueno',
#  'buena comida yucateca',
#  'temor equivocarme lugar excelencia ciudad mexico comida yucateca simplemente recomendable obviamente panuchos sopa lima cochinita postres tambien deliciosos vale pena probar variedad cervezas propias carat asi cocteles bebida local xtabentun',
#  'sopa lima rica tacos cochinita tambien platanos crema sabrosos siento pequenas porciones relacion precio chiquito precio grande',
#  'buena atencion comida bastante sabrosa',
#  'comida yucateca rica',
#  'buena comida yucateca cercana puedes comer merida',
#  'sabores calidad cumplidores servicio espectacular precio tal vez elevado recomiendo',
#  'bien caro',
#  'platillos excelentes sazon sabores deliciosos',
#  'riquisima comida yucateca lugar pasar excelente tarde amigos familiares',
#  'buena comida muc bi pollo rico tipico dia muertos dulces riquisimos recomiendo',
#  'restaurante excelente aspectos platillos servicio ambiente mesero alejandro mejor',
#  'bueno buen precio',
#  'excelente sitio comida yucateca',
#  'excelente lugar valle comida yucateca entradas postre pibipollo delicioso maridaje interesante sugerido meseros extraordinaria atencion marco',
#  'excelente comida yucateca tradicional',
#  'excelente lugar comer comida tipica sureste mexico',
#  'mu rica comida agradable lugar',
#  'exquisito sabor comida yucateca',
#  'amantes comida yucateca comida mexicana general lugar imperdible altamente recomendable dado 5 estrellas primer lugar atencion servicio fenomenales encantaron gran punto favor despues trajeron alimentos mas rapido promedio restaurante disfrute muchisimo sopa lima igual mas rica comido merida probar ademas platillos si ko sabes pedir ayuda bastante precios buenos calidad servicio recibe cambio 5 estrellas',
#  'personal presenta momento atender comensal porciones pequenas precios elevados acuerdo tamano porcion',
#  'buen sason yucateco',
#  'excelente sabor yucateco lugar super agradable',
#  'pianista ambiente comida',
#  'regular',
#  'bien tardaron servir postres deliciosa comida atencion general bien',
#  'alimentos sabor rico lugar super limpio servicio estupendo pongo 5 estrellas venado comi tan rico cochinita comieron demas cafe delicioso',
#  'rico buen servicio',
#  'buena comida buenos precios voy volver duda',
#  'excelente sazon calidad calidez personal',
#  'espacios agradables excelente comida atencion',
#  'excelente lugar probar comida yucateca servicio igual manera bastante bueno',
#  'excelente comid yucateca',
#  'servicio bueno comida llego fria salbute remojado agua lechuga sopa lima tan condimentada apenas percibia sabor lima tamal rico',
#  'deliciosos platillos',
#  'probe rico',
#  'buen sabor comida atencion adecuada oferta cervezas tradicionales buena experiencia recomendable',
#  'comoda rica atencion excelente',
#  'agradable lugar comida yucateca horario reducido',
#  'buen lugar comer comida artesanal yucateca excelente ambiente servicio',
#  'definitivamente lugar recomendable vivir experiencia yucateca platillos deliciosos pan cazon increible cocteleria sensacional atencion personal excelente',
#  'lugar x',
#  'delicioso',
#  'comida yucateca puedes encontrar basico mas',
#  'rica comida',
#  'caro',
#  'excelente sabor atencion',
#  'bueno',
#  'sabroso agradable lugar buena atencion acompanados musica piano gusto',
#  'lugar bonito carta amplia buena comida relacion precio buena rico unico seria cochinita seca falta caldito sabor',
#  'buena comida musica ambiente',
#  'rica comida yucateca platillos temporada',
#  'felicidades buen menu buen sazon excelente servicio recomendable prueben entrada postre',
#  'comida rica meseros deben mas atentos',
#  'buen servicio',
#  'excelente cocina yucateca hermosos eventos nocturnos tango',
#  'buen servicio amable s',
#  'comida atencion siempre excelentes',
#  'bueno',
#  'comida excelente precios',
#  'familia sido clientes anos lugar sigue dando excelente servicio calidad alimentos atendian fundadores negocio',
#  'mala atencion cuanto manejo pandemia limpian mesa tampoco dan gel antibacterial colmo dejan lavarte manos menos pasar bano',
#  'lugar aire libre agradable buen sabor',
#  'mejores mundo',
#  'siguen siendo buenas carnitas incrementado precios forma desproporcional',
#  'ricas carnitas deliciosos nopales excelente',
#  'rico aseado buen servicio',
#  'super recomendado buenos precios sabor increible quesadillas sesos chuleta wow sana distancia estan mesas afuera buen espacio cada primera vez voy fan',
#  'mas menos tenian queria',
#  'tacos carnitas bastante sabrosos salsa igualmente sabor complementa perfectamente carne',
#  'ricas completo nopales salsas esquisitas',
#  'deliciosamente conocido nina',
#  'riquisimas mejores l valle cdmx',
#  'delicioso',
#  'deliciosas carnitas costilla deliciosa flan tambien ambiente relajado excelente ir familia amigos solas cuidados limpieza seguridad contingencia sanitaria',
#  'excelente servicio',
#  'tacos deliciosos mejor nopales salsita pico gallo uff gusta ahora dan nopales taco servian ollita barro solo gusta comer parque gusta',
#  'pesima atencion',
#  'buen sabor atencion buena lugar basta agradable recomendable',
#  'mejores carnitas cdmx nopales supremos',
#  'ricas estan tomando muchas precauciones evitar contagios tiempos dificiles felicitaciones establecimiento',
#  'buenas carnitas quieren cobrar tortillas limones servilletas',
#  'costilla entera mejores',
#  'ricas carnitas',
#  'excelente comida deliciosa',
#  'riquisima',
#  'maravillosas carnitas',
#  'buena atencion servicio bueno carnitas super ricas',
#  'excelente servico atencion carnitas ufff unicas inigualables',
#  'excelente servicio',
#  'amo nopales lugar riquisimo',
#  'exelente',
#  'mala actitud sirve carnitas aguantabas sabor ahora carnitas viejas saladas dia volveria regresar tiempo',
#  'caras cortan bien carnitas nina verdura',
#  'hace pesimo servicio atienden si favor aparte cobran todooooooo salsa',
#  'vez atendio mostrador llevar empezo reganar senora verme cara tonto burlandose decir queria carne deshebrada mal trato mejor mal espero siguiente vaya cambien actitud',
#  'falta sabor carne mas frescura',
#  'solo falta aceptar tarjeta',
#  'excelente lugar agradable carne buena calidad excelente atencion',
#  'excelentes deliciosas ademas ambiente agradable familiar mesas afuera si terraza recomiendo ampliamente',
#  'tacos buenos atencion senora atendio dieron ganas regresar',
#  'mas menos',
#  'encantan carnitas don rafa nopalutos lujo',
#  'aunque comido mesa ahi carnitas buenisimas jugosas buen sabor salsas tambien buenas nopales ricos buen precio recomendadisimo',
#  'mejores carnitas cdmx',
#  'excelentes precios',
#  'siempre exquisitas carnitas nopalitos q decir',
#  'ricas carnitas',
#  'demoran atenderte ponen atencion pides comida rica lugar ir familia si gusta esperar comer recomendable si van mucha hambre ultimo solo defino lugar recomiendo ir comer',
#  'excelente lugar comer',
#  'excelente carnitas',
#  'bien',
#  'mejores carnitas cdmx 3 nopales mejor',
#  'carnitas buen sabor super recomendable',
#  'caro estan buenas',
#  'primera vez lugar gusto carnitas ricas quesadillas sesos deliciosas lugar tranquilo barato 20 tacos claro regreso',
#  'deliciosas carnitas',
#  'tacos estan buenos gustaron',
#  'buenos',
#  'buena comida falta atencion',
#  'super ricas personal atento lugar limpio',
#  'bastante rico',
#  'excelente carne',
#  'buen sabor precio',
#  'sabroso',
#  'buenas carnitas',
#  'buenas carnitas buen servicio',
#  'agradabilisimo lugar comer interior reducido adecuado varias mesas decoracion ad hoc agradable tambien ocupan area exterior jardin publico adaptado bien atender mesas sombrilla ricos aire libre carnitas ricas aderezos tambien puede complementar quesadillas antojitos postres buenos',
#  'atencion buena orden sirven acompanamiento nopales ajos asados juliana delicia tacos sirven sola tortilla abundantes digamos carnitas bien extraordinario cumplidoras',
#  'ummmm riquisimas',
#  'buen sabor',
#  'riquisimas carnitas buen precio',
#  'buenas carnitas gustan beber alguna cerveza aqui lugar expenden',
#  'delicioso saludables',
#  'buenos tacos super rico',
#  'buena opcion comer cerca trabajo higiene precios accesibles',
#  'rico',
#  'bonito lugar aunque carnitas tan buenas',
#  'buen servicio',
#  'agradable lugar puede comer dentro establecimiento carnitas estan ricas flan gusto buena atencion',
#  'excelentes servicio tradicion visitarlos si andas rumbos coapa',
#  'exquisito estilo preparar carnitas',
#  'buena atencion rapidez calidad recomendamos',
#  'ricas limpio excelente atencion',
#  'mejores sur',
#  'exquisitas carnitas',
#  'ricas',
#  'delicia sabor familia anos recomendado',
#  'excelente atencion productos super 10',
#  'rico buen servicio',
#  'deliciosas carnitas',
#  'pongo 4 estrellas mejores carnitas vas probar saladas gusto unico rescatable maciza cuanto nivel sal general buenas costo considero elevado adjudico zona considera costo promedio 100 150 persona prueba quesadillas arroz si estan buenos',
#  'ricas carnitas mesas afuera si quieres acompane mascota complicado buscar estacionamiento',
#  'hamburguesas gnomo recomendables x calidad sabor preparacion aunque podrian parecer sencillas buenas aderezo queso combina perfecto',
#  'excelente lugar disfrutar hamburguesas papas fritas',
#  'buenas hamburguesas',
#  'excelente servicio hamburguesas',
#  'buenisima comida divertido concepto gnomo si alguien alto',
#  'hamburguesa super gnomo mejor mundo fascinantes chiles vinagre caseros unicos anos anos disfrutar mejores hamburguesas df ahora cdmx unicas simplemente mejores aderezo especial gnomo da sabor unico aderezo ensalada papas adictivo cerveza barril buena temperatura simplemente exquisita pierdas oportunidad',
#  'ricas',
#  'comida realmente exquisita preparada momento mejores ingredientes frescos termina conquistar excelente servicio concepto original sur ciudad gracias especialmente margarita pedro',
#  'excelente calidad atencion precio inmejorable',
#  'hamburguesas ricas recomendable',
#  'aderezo queso azul da sabor especial dejen probarlo',
#  'mejores hamburguesas siempre ponen primero cliente hamburguesa supergnomo personal gusta mas si ido lugar deberias probarla inicio ademas porcion calabazas rellenas seguro si asi llamen acompanan sabor peculiar servicio adecuado',
#  'hamburguesas realmente ricas buen precios estilo clasica hamburguesa americana complementos ofrecen version completa super gnomo simples sazon punto importante si gusta bien cocida carne debes pedirla tal termino contrario termino punto',
#  'hamburguesas unicas rn du tipo deliciosas super gnomo excelente',
#  'excelente sabor hamburguesas cerveza barril',
#  'mejores hamburguesas',
#  'buena calidad alimentos solamente pedir bien cocidas carne hamburguesa general bueno servicio',
#  'siempre pido hamburguesa vegetariana gusta cambian carne portobello malteadas deliciosas',
#  'excelente servicio gente amable hamburguesas estan riquisimas ambiente adecuado ir pareja familia gustes siempre estan disposicion meseros recomiendo malteada vainilla helado cremoso',
#  'desilucion hamburguesas parecen juguete ofrecen tocino champinones unicamente traen cuadrito tocino recomiendo',
#  'mucha limpieza pues buen servicio siempre',
#  'carne suave sabrosita',
#  'siempre riquisimo',
#  'buena comida buen servicio',
#  'excelente atencion rica comida buen precio',
#  'amo calabazas capeadas sabor hamburguesas ultra recomendable lugar',
#  'calidad precio mejores hamburguesas ciudad mexico',
#  'deliciosas',
#  'hamburguesas buenisimas puede pedir especificaciones papas mas doradas menos doradas agua si hielos etc rapidos eficientes limpios acepta tarjetas credito efectivo',
#  'adoro ku3',
#  'mejores hamburguesas anos',
#  'excelente',
#  'lugar rico comer 100 recomendable hamburguesas gnomo',
#  'gustan calabacitas hamburguesa gusta carne congelada',
#  'favoritas variedad presupuestos malteada nuez deliciosa opcion vegetariana portobello menu preparan problema delicioso si aderezo acompanar papas',
#  'chingonas saben neta',
#  'mejores hamburguesas sur quiza ciudad joya local autentica super gnomo cerveza barril calabacitas empanizadas malteadas delicioso hecho mucha dedicacion excelente servicio',
#  'mejores rumbo',
#  'mejores hamburguesas sur ciudad unico malo lugar aceptan tarjetas credito debito',
#  'saben si estan entregando domicilio contingencia',
#  'excelente lugar rico recomiendo hamburguesa super gnomo',
#  'comida deliciosa',
#  'pesimo servicio hice orden recogerlas tenian hechas pan tenian pesimo',
#  'super gnomo deliciosa enchilafas tambien ricas falta probar chilaquiles ahhh hotcakes tambien ricos',
#  'lugar tradicional hamburguesas barrio embargo creo hamburguesas hacen cada vez mas pequenas sabor sigue siendo mismo rico recomendables calabazas capeadas',
#  'excelente lugar comida deliciosa',
#  'hamburguesas ricas',
#  'delicia lugar',
#  'mejores cangreburguers comido',
#  'lugar pequeno limpio atencion rapida hamburguesa mignon champinones rica',
#  'bellisimo lugar excelente sabor buen precio',
#  'decente',
#  'mejor chela hamburguesas cdmx',
#  'deliciosas hamburguesas abundantes papas buena porcion precio sitio acogedor seguro',
#  'excelente',
#  'solia ser bastante mejor hamburguesas papas sabor creo unico mantiene bien encurtidos',
#  'lugar solia ser mejor hamburguesas ahora bastante promedio papas fritas malas calzas rebozadas especialidad lugar ahora capeado dulce aire acondicionado tan intenso comida enfrio 15 minutos',
#  ...]

# %%
topic_model = BERTopic(language="multilingual")
topics, probs = topic_model.fit_transform(textos)
topic_model.get_topic_info()
# Out:
#      Topic  Count                                         Name
# 0       -1   2355                       -1_lugar_si_comida_mas  \
# 1        0    176          0_precios_precio_accesibles_surtido
# 2        1    173            1_lugar_comida_yucateca_agradable
# 3        2    138  2_excelente_excelentes_perfecto_simplemente
# 4        3    131                 3_precios_precio_comida_rica
# ..     ...    ...                                          ...
# 176    175     11         175_cenar_fine_tranquilamente_dining
# 177    176     10           176_tacos_recibirla_paro_chiquitas
# 178    177     10     177_exquisita_mojarras_grandiosa_viernes
# 179    178     10              178_agua_cielos_tanques_splenda
# 180    179     10       179_guadalajara_ahogadas_tortas_birote
#
#                                         Representation
# 0    [lugar, si, comida, mas, bien, comer, sabor, a...  \
# 1    [precios, precio, accesibles, surtido, buenos,...
# 2    [lugar, comida, yucateca, agradable, deliciosa...
# 3    [excelente, excelentes, perfecto, simplemente,...
# 4    [precios, precio, comida, rica, altos, costos,...
# ..                                                 ...
# 176  [cenar, fine, tranquilamente, dining, coqueto,...
# 177  [tacos, recibirla, paro, chiquitas, comerlo, p...
# 178  [exquisita, mojarras, grandiosa, viernes, eleg...
# 179  [agua, cielos, tanques, splenda, avia, equipos...
# 180  [guadalajara, ahogadas, tortas, birote, export...
#
#                                    Representative_Docs
# 0    [excelente experiencia menu definitivamente pr...
# 1    [rico buen precio, rico buen precio, buen precio]
# 2    [comida excelente lugar agradable buena atenci...
# 3                    [excelente, excelente, excelente]
# 4    [comida rica buen precio, rica comida buen pre...
# ..                                                 ...
# 176  [buen lugar comer cenar atencion excelente, ex...
# 177  [opcion vasito consome plato birria tacos dora...
# 178  [comida exquisita, exquisita comida, comida ex...
# 179  [servicio bueno platillos excelentes creo debe...
# 180  [buen servicio comida rica tortas ahogadas gen...
#
# [181 rows x 5 columns]

# %%
aux = topic_model.get_topic_info()

new_res = {}
for t in aux['Topic'].unique():
    lista = []
    res = topic_model.get_topic(t, full=True)
    for pair in res['Main']:
        lista.append(pair[0])
    new_res[t] = lista
aux = pd.DataFrame.from_dict(new_res, orient='index')
aux.columns = ['Tema 1', 'Tema 2', 'Tema 3', 'Tema 4', 'Tema 5', 'Tema 6', 'Tema 7','Tema 8', 'Tema 9', 'Tema 10']
display(aux)
common_values = aux.stack().value_counts()
common_values.head(10)
# Out:
#            Tema 1      Tema 2          Tema 3       Tema 4        Tema 5
# -1          lugar          si          comida          mas          bien  \
#  0        precios      precio      accesibles      surtido        buenos
#  1          lugar      comida        yucateca    agradable     deliciosa
#  2      excelente  excelentes        perfecto  simplemente  siemplemente
#  3        precios      precio          comida         rica         altos
# ...           ...         ...             ...          ...           ...
#  175        cenar        fine  tranquilamente       dining       coqueto
#  176        tacos   recibirla            paro    chiquitas       comerlo
#  177    exquisita    mojarras       grandiosa      viernes      elegante
#  178         agua      cielos         tanques      splenda          avia
#  179  guadalajara    ahogadas          tortas       birote     exportado
#
#              Tema 6        Tema 7       Tema 8      Tema 9        Tema 10
# -1            comer         sabor     atencion        solo      platillos
#  0            sazon    razonables         rico    relacion      accesible
#  1           bonito          rica    excelente   alimentos      increible
#  2    excelentisimo         zason    perfectas       atole     atendieron
#  3           costos     accesible         caro  accesibles     razonables
# ...             ...           ...          ...         ...            ...
#  175           cena     tranquila       ciento        cien          chica
#  176        previas   deliociosas    tezozomoc      pelear    tortillinas
#  177      increible  espectacular       comida        rica         bonito
#  178        equipos        bombeo  refacciones         eau  purificadores
#  179       braseado       opinara   degustamos         sot    recomiendan
#
# [181 rows x 10 columns]
#              67
# comida       14
# servicio     14
# rico         13
# excelente    12
# lugar        10
# buen         10
# rica          9
# sabor         8
# atencion      8
# Name: count, dtype: int64

# %%
topic_model.get_topic(0, full=True)
# Out:
# {'Main': [('precios', 0.046740180278884144),
#   ('precio', 0.04530831502910763),
#   ('accesibles', 0.02753516700220115),
#   ('surtido', 0.021289618744527887),
#   ('buenos', 0.016178638495995608),
#   ('sazon', 0.013973630116078791),
#   ('razonables', 0.013463356065816813),
#   ('rico', 0.013017011526141268),
#   ('relacion', 0.012975592176890193),
#   ('accesible', 0.012776206001294284)]}

# %%
topic_model.visualize_topics()
